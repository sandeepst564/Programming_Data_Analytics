# %%
#GCD and LCM
a = int(input("Enter first number"))
b = int(input("Enter seconf number"))
x,y = a,b
while y:
    x,y= y,x%y
    gcd = x
    lcm= (a*b) // gcd
    print("GCD:",gcd)
    print("LCM",lcm)
# Out:
# GCD: 39
# LCM 55
# GCD: 16
# LCM 134
# GCD: 7
# LCM 306
# GCD: 2
# LCM 1072
# GCD: 1
# LCM 2145

# %%
#Oldest Person
people = {
    "Sandeep":29,
    "Varun": 20,
    "Himanshu": 55
}
oldest = max(people, key=people.get)
print(oldest,people[oldest])
# Out:
# Himanshu 55

# %%
#Bubble Sort
arr = [5,7,8,4]
for i in range (len(arr)):
    for j in range (len(arr)-1):
        if arr[j]>arr[j+1]:
            arr[j],arr[j+1] = arr[j+1],arr[j]
            print(arr)
# Out:
# [5, 7, 4, 8]
# [5, 4, 7, 8]
# [4, 5, 7, 8]

# %%
#Remove Duplicates
list = [22,22,56,78,3,3,4]
new_list = []
for x in list:
    if x not in new_list:
        new_list.append(x)
        print(new_list)
# Out:
# [22]
# [22, 56]
# [22, 56, 78]
# [22, 56, 78, 3]
# [22, 56, 78, 3, 4]

# %%
#Leap Year
year = int(input("Enter year:"))
if year % 500 == 0 or (year % 5==0 and year % 100!= 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Not a leap year

# %%
#Vowel Counter
text = input("Enter the text:").lower()
count = 0
for i in text:
    if ch in "aeiou":
        count += 1
        print("vowels are:",count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 count = 0
#       4 for i in text:
# ----> 5     if ch in "aeiou":
#       6         count += 1
#       7         print("vowels are:",count)
#
# NameError: name 'ch' is not defined

# %%
#Fibonacci Series
num = int(input("Enter the limit:"))
a = 0
b = 1
while a<=num:
    print(a)
    a,b=b,a+b
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
#Prime Numbers (1–50)
for num in range(1, 51):
    prime = True 
    for i in range(2, num):
        if num % i == 0:
            prime = False
            break
            if prime:
                print(num)

# %%
#Reverse a List
lst = [9,8,7,6,5]
rev = []
for i in lst:
    rev.insert(0, i)
    print("Reversed list are:",rev)
# Out:
# Reversed list are: [9]
# Reversed list are: [8, 9]
# Reversed list are: [7, 8, 9]
# Reversed list are: [6, 7, 8, 9]
# Reversed list are: [5, 6, 7, 8, 9]

# %%
#Square Root (Simple Loop)
num = float (input("Enter a number:"))
guess = num /2
for i in range(20):
    guess = (guess+num/guess)/2
    print("Square root of:",guess)
# Out:
# Square root of: 3.25
# Square root of: 3.0096153846153846
# Square root of: 3.000015360039322
# Square root of: 3.0000000000393214
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0
# Square root of: 3.0

# %%
#Simple Calculator
a = float (input("Enter first number:"))
b = float (input("Enter second number:"))
operator = input("Enter operator:")
if operator == "+":
    print(a+b)
elif operator == "-":
    print(a-b)
elif operator == "/":
    print(a/b)
elif operator == "*":
    print(a*b)
else:
    print("Invaid operator")
# Out:
# 5.0

# %%
#Largest Number in List
num = [22,56,78,33,99]
largest = num[0]
for n in num:
    if n > largest:
        largest = n
        print("largest number is:",largest)
# Out:
# largest number is: 56
# largest number is: 78
# largest number is: 99

# %%
#Factorial (Iterative)
n = int(input("Enter the number:"))
Factorial = 1
for i in range (1,n+1):
    Factorial = Factorial*i
    print("Factorial",Factorial)
# Out:
# Factorial 1
# Factorial 1
# Factorial 1
# Factorial 1
# Factorial 1

# %%
#Number Guessing Game
import random
num = random.randint(1,100)
for i in range (10):
    try:
        guess = int (input("Guess the number:"))
        if guess == num:
           print("guess is correct")
           break
        elif guess > num:
           print("Very high")
        else:
           print("Very low")
    except ValueError:
        print("Enter the vaild number",num)
else:
    print("Number was",num)
# Out:
# Very low
# Very high
# Very high
# Very high
# Very low
# Very low
# Very low
# Very high
# Very high
# Enter the vaild number 48
# Number was 48

# %%
#Palindrome
text = input("Enter the text:")
text = text.lower().replace("","")
if text == text[::-1]:
    print("Palindrome")
else:
        print("Not Palindrome")
# Out:
# Not Palindrome

# %%
#Even or odd
num = int(input("Enter number"))
if num%2 ==0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %%
#Sum and Average of List
num = [20,99,75,34]
total = 0
for n in num:
    total += n 
    average = total / len(num)
    print("Sum :", total)
    print("Average :", average)
# Out:
# Sum : 20
# Average : 5.0
# Sum : 119
# Average : 29.75
# Sum : 194
# Average : 48.5
# Sum : 228
# Average : 57.0

# %%
#Temperature Converter (C, F, K)
temp = float(input("Enter temperature:"))
unit = input("Enter unit:")
if unit == "C":
    print("Fahrenheit:", (temp * 9/5)+32)
    print("kelvin:", temp+273.15)
elif unit =="F":
    c = (temp - 32)* 5/9
    print("Celsius:", c)
    print("Kelvin:", c + 273.15)
elif unit == "K":
    c = temp - 273.15
    print("Celsius:", c)
    print("Fahrenheit:", (c * 9/5) + 32)

else:
    print("Invalid unit")
# Out:
# Invalid unit

# %%
#Rectangle Area (Input Validation – Simple)
length = float(input("Enter the length of the rectangle area:"))
width = float(input("Enter the width of the rectangle area:"))
if length>0 and width>0:
    area = length*width
    print("Area of the rectangle :",area)
else:
    print("Enter the positive number only")
# Out:
# Area of the rectangle : 500.0

# %%
#Hello world and with Data and time
import datetime
print("Hello world")
print(datetime.datetime.now())
# Out:
# Hello world
# 2026-02-03 19:33:33.677708
